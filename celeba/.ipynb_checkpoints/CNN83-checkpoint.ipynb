# %%
import numpy as np
import pandas as pd
import PIL
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D
from tensorflow.keras.preprocessing import image

# %%
attr_data_path = "list_attr_celeba.csv"
images_data_path = "C:/Users/foreh/Documents/celeba/greyscale"
images_data_size = 20000 

tf.keras.backend.clear_session()
width = 178
height = 218
x_ = 100                            # new value of x
image_size_ratio = width / height    # dimensions ratio
y_ = int(image_size_ratio * x_)  
model = Sequential()
model.add(tf.keras.Input(shape=(height, width,1)))
model.add(tf.keras.layers.Normalization())

model.add(Conv2D(filters=32,kernel_size=(3,3),padding = 'same', kernel_regularizer='l2'))
model.add(Conv2D(filters=8, kernel_size=(3,3), padding='same', kernel_regularizer='l2'))
model.add(tf.keras.layers.Normalization())

model.add(Conv2D(filters=4, kernel_size=(3, 3), padding='same', kernel_regularizer='l2'))
model.add(MaxPooling2D(pool_size=2))

model.add(Dropout(0.2))

model.add(Conv2D(filters=32,kernel_size=(3,3),padding = 'same', kernel_regularizer='l2'))
model.add(Conv2D(filters=8,kernel_size=(2,2),padding = 'same', kernel_regularizer='l2'))
model.add(tf.keras.layers.Normalization())

model.add(Conv2D(filters=4, kernel_size=(3, 3), padding='same', kernel_regularizer='l2'))
model.add(MaxPooling2D(pool_size=2))

model.add(Dropout(0.2))

model.add(Conv2D(filters=16,kernel_size=(3,3),padding = 'same', kernel_regularizer='l2'))
model.add(Conv2D(filters=8,kernel_size=(2,2),padding = 'same', kernel_regularizer='l2'))
model.add(tf.keras.layers.Normalization())

model.add(Conv2D(filters=4, kernel_size=(3, 3), padding='same', kernel_regularizer='l2'))
model.add(MaxPooling2D(pool_size=4))

model.add(Conv2D(filters=16, kernel_size=(3,3)))
model.add(Conv2D(filters=16, kernel_size=(2,2)))
model.add(tf.keras.layers.AveragePooling2D(pool_size=2))

model.add(tf.keras.layers.Normalization())

model.add(Flatten())
model.add(Dense(64))
model.add(Dense(32))
model.add(Dense(48))
model.add(Dense(16))
model.add(Dense(4, activation='sigmoid'))
original_image_size = (width,height)
df_org = pd.read_csv(attr_data_path)

for i in range(10, 100):
    if (i > 1):
        model = tf.keras.models.load_model('cnn82_checkpoints/iter'+str(i-1))
        print("model loaded: iter"+str(i-1))
        print("training model "+str(i))
    df = pd.DataFrame()
    if((i+1) % 10 == 0):
        df = df_org[(1+images_data_size*(i%10)):202600]
    else:
        df = df_org[(1+images_data_size*(i%10)):images_data_size*((i+1)%10)]
    df = df.replace(-1,0)
    #print(df.head(5))
    images_data = list()
    for idx in range(df.shape[0]):
        path = "{}/{}".format(str(images_data_path),str(df.iloc[idx].image_id))
        image = PIL.Image.open(path)
        image_array = np.asarray(image)
        images_data.append(image_array)
    images_data = np.array(images_data)
    def image_from_index(index, size=(original_image_size), path=images_data_path):
        path = "{}/{}".format(str(path),str(df.iloc[index].image_id))
        # to read the image
        image = PIL.Image.open(path).resize(size)
        image_array = np.asarray(image)

        return image_array
    images = images_data # list of array of images
    labels = df[["image_id", "Bangs", "Straight_Hair", "Wavy_Hair", "Wearing_Hat"]]  # dataframe of image features
    train_images,test_images,train_labels,test_labels = train_test_split(images,labels,test_size=0.3,random_state=(i%6))
    y_test=test_labels.drop(["image_id"],axis=1)
    y_train=train_labels.drop(["image_id"],axis=1)

    X_test=test_images
    X_train=train_images
    #X_train = tf.expand_dims(X_train, axis=-1)
    print("Samples Training Set:",len(X_train))
    X_test, X_val, y_test, y_val=train_test_split(X_test, y_test,test_size=0.5,random_state=(i%5))
    print("Samples in Validation Data:",len(X_val))
    print("Samples in Test Data:",len(X_test))
    x_ = original_image_size[0]
    y_ = original_image_size[1]
    BATCH_SIZE = (8)
    print("Batch size: " + str(BATCH_SIZE))
    if False and i%3 == 1:
          model.compile(optimizer = "nadam",loss="binary_crossentropy",metrics = [tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 'binary_accuracy'])
    elif True or i%3 == 2 or i%3 == 0:
          print("SGD")
          opt = tf.keras.optimizers.SGD(learning_rate=0.001)
          model.compile(optimizer = opt,loss="binary_crossentropy",metrics = [tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 'binary_accuracy'])
    else:
          print("ADAM")
          opt = tf.keras.optimizers.Adam(learning_rate=0.001)
          model.compile(optimizer = opt,loss="binary_crossentropy",metrics= ["binary_accuracy"])#tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 'binary_accuracy'])
    training_process = model.fit(X_train,y_train,epochs = 5,validation_data = (X_val,y_val),batch_size=BATCH_SIZE,shuffle = True)
    model.save('cnn82_checkpoints/iter'+str(i))
    print("Model " + str(i) +"evaluating:")
    model.evaluate(X_val,y_val)
    tf.keras.backend.clear_session()
# Out:
# model loaded: iter9
# training model 10
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 68s 37ms/step - loss: 0.3248 - precision: 0.7370 - recall: 0.4003 - binary_accuracy: 0.8643 - val_loss: 0.3204 - val_precision: 0.7293 - val_recall: 0.4297 - val_binary_accuracy: 0.8654
# Epoch 2/5
# 1750/1750 [==============================] - 65s 37ms/step - loss: 0.3240 - precision: 0.7367 - recall: 0.3985 - binary_accuracy: 0.8641 - val_loss: 0.3202 - val_precision: 0.7171 - val_recall: 0.4433 - val_binary_accuracy: 0.8651
# Epoch 3/5
# 1750/1750 [==============================] - 66s 38ms/step - loss: 0.3239 - precision: 0.7331 - recall: 0.3994 - binary_accuracy: 0.8637 - val_loss: 0.3208 - val_precision: 0.7163 - val_recall: 0.4587 - val_binary_accuracy: 0.8667
# Epoch 4/5
# 1750/1750 [==============================] - 67s 38ms/step - loss: 0.3242 - precision: 0.7275 - recall: 0.4029 - binary_accuracy: 0.8633 - val_loss: 0.3233 - val_precision: 0.7320 - val_recall: 0.4035 - val_binary_accuracy: 0.8627
# Epoch 5/5
# 1750/1750 [==============================] - 67s 38ms/step - loss: 0.3234 - precision: 0.7342 - recall: 0.4033 - binary_accuracy: 0.8643 - val_loss: 0.3191 - val_precision: 0.7549 - val_recall: 0.3967 - val_binary_accuracy: 0.8650
5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3187 - precision: 0.7284 - recall: 0.4160 - binary_accuracy: 0.8655 - val_loss: 0.3226 - val_precision: 0.7545 - val_recall: 0.3749 - val_binary_accuracy: 0.8602
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter16\assets
# Model 16evaluating:
# 94/94 [==============================] - 4s 36ms/step - loss: 0.3226 - precision: 0.7545 - recall: 0.3749 - binary_accuracy: 0.8602
# model loaded: iter16
# training model 17
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3219 - precision: 0.7272 - recall: 0.3951 - binary_accuracy: 0.8636 - val_loss: 0.3216 - val_precision: 0.7543 - val_recall: 0.3746 - val_binary_accuracy: 0.8627
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3214 - precision: 0.7342 - recall: 0.3998 - binary_accuracy: 0.8651 - val_loss: 0.3197 - val_precision: 0.7634 - val_recall: 0.3673 - val_binary_accuracy: 0.8628
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3209 - precision: 0.7305 - recall: 0.3975 - binary_accuracy: 0.8643 - val_loss: 0.3211 - val_precision: 0.7392 - val_recall: 0.3973 - val_binary_accuracy: 0.8635
# Epoch 4/5
# 1750/1750 [==============================] - 65s 37ms/step - loss: 0.3211 - precision: 0.7311 - recall: 0.3948 - binary_accuracy: 0.8641 - val_loss: 0.3238 - val_precision: 0.6985 - val_recall: 0.4549 - val_binary_accuracy: 0.8637
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3214 - precision: 0.7320 - recall: 0.3973 - binary_accuracy: 0.8645 - val_loss: 0.3195 - val_precision: 0.7351 - val_recall: 0.3964 - val_binary_accuracy: 0.8628
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter17\assets
# Model 17evaluating:
# 94/94 [==============================] - 4s 36ms/step - loss: 0.3195 - precision: 0.7351 - recall: 0.3964 - binary_accuracy: 0.8628
# model loaded: iter17
# training model 18
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3095 - precision: 0.7385 - recall: 0.3924 - binary_accuracy: 0.8719 - val_loss: 0.3116 - val_precision: 0.6919 - val_recall: 0.3916 - val_binary_accuracy: 0.8691
# Epoch 2/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3092 - precision: 0.7340 - recall: 0.3925 - binary_accuracy: 0.8713 - val_loss: 0.3116 - val_precision: 0.7381 - val_recall: 0.3622 - val_binary_accuracy: 0.8718
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3084 - precision: 0.7396 - recall: 0.3919 - binary_accuracy: 0.8720 - val_loss: 0.3101 - val_precision: 0.7307 - val_recall: 0.3677 - val_binary_accuracy: 0.8716
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3079 - precision: 0.7404 - recall: 0.3993 - binary_accuracy: 0.8729 - val_loss: 0.3147 - val_precision: 0.6914 - val_recall: 0.4185 - val_binary_accuracy: 0.8715
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3079 - precision: 0.7385 - recall: 0.3953 - binary_accuracy: 0.8722 - val_loss: 0.3097 - val_precision: 0.7278 - val_recall: 0.3597 - val_binary_accuracy: 0.8704
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter18\assets
# Model 18evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3097 - precision: 0.7278 - recall: 0.3597 - binary_accuracy: 0.8704
# model loaded: iter18
# training model 19
# Samples Training Set: 15818
# Samples in Validation Data: 3390
# Samples in Test Data: 3390
# Batch size: 8
# SGD
# Epoch 1/5
# 1978/1978 [==============================] - 74s 37ms/step - loss: 0.3232 - precision: 0.7353 - recall: 0.4383 - binary_accuracy: 0.8631 - val_loss: 0.3155 - val_precision: 0.7544 - val_recall: 0.4340 - val_binary_accuracy: 0.8664
# Epoch 2/5
# 1978/1978 [==============================] - 72s 37ms/step - loss: 0.3219 - precision: 0.7348 - recall: 0.4413 - binary_accuracy: 0.8634 - val_loss: 0.3176 - val_precision: 0.7408 - val_recall: 0.4473 - val_binary_accuracy: 0.8660
# Epoch 3/5
# 1978/1978 [==============================] - 73s 37ms/step - loss: 0.3214 - precision: 0.7363 - recall: 0.4438 - binary_accuracy: 0.8639 - val_loss: 0.3165 - val_precision: 0.7154 - val_recall: 0.4836 - val_binary_accuracy: 0.8661
# Epoch 4/5
# 1978/1978 [==============================] - 73s 37ms/step - loss: 0.3214 - precision: 0.7286 - recall: 0.4414 - binary_accuracy: 0.8625 - val_loss: 0.3161 - val_precision: 0.7617 - val_recall: 0.4317 - val_binary_accuracy: 0.8671
# Epoch 5/5
# 1978/1978 [==============================] - 73s 37ms/step - loss: 0.3216 - precision: 0.7361 - recall: 0.4414 - binary_accuracy: 0.8636 - val_loss: 0.3173 - val_precision: 0.7398 - val_recall: 0.4551 - val_binary_accuracy: 0.8668
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter19\assets
# Model 19evaluating:
# 106/106 [==============================] - 4s 39ms/step - loss: 0.3173 - precision: 0.7398 - recall: 0.4551 - binary_accuracy: 0.8668
# model loaded: iter19
# training model 20
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 37ms/step - loss: 0.3210 - precision: 0.7323 - recall: 0.4075 - binary_accuracy: 0.8648 - val_loss: 0.3136 - val_precision: 0.7072 - val_recall: 0.4517 - val_binary_accuracy: 0.8673
# Epoch 2/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3206 - precision: 0.7336 - recall: 0.4019 - binary_accuracy: 0.8643 - val_loss: 0.3111 - val_precision: 0.7102 - val_recall: 0.4517 - val_binary_accuracy: 0.8678
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3198 - precision: 0.7379 - recall: 0.4050 - binary_accuracy: 0.8653 - val_loss: 0.3099 - val_precision: 0.7561 - val_recall: 0.4009 - val_binary_accuracy: 0.8686
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3191 - precision: 0.7385 - recall: 0.4071 - binary_accuracy: 0.8656 - val_loss: 0.3137 - val_precision: 0.7466 - val_recall: 0.4069 - val_binary_accuracy: 0.8681
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.
5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3182 - precision: 0.7338 - recall: 0.4086 - binary_accuracy: 0.8658 - val_loss: 0.3264 - val_precision: 0.7539 - val_recall: 0.3732 - val_binary_accuracy: 0.8622
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter24\assets
# Model 24evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3264 - precision: 0.7539 - recall: 0.3732 - binary_accuracy: 0.8622
# model loaded: iter24
# training model 25
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3178 - precision: 0.7339 - recall: 0.4198 - binary_accuracy: 0.8672 - val_loss: 0.3157 - val_precision: 0.7350 - val_recall: 0.4404 - val_binary_accuracy: 0.8680
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3180 - precision: 0.7355 - recall: 0.4171 - binary_accuracy: 0.8671 - val_loss: 0.3167 - val_precision: 0.7813 - val_recall: 0.3646 - val_binary_accuracy: 0.8645
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3176 - precision: 0.7349 - recall: 0.4131 - binary_accuracy: 0.8666 - val_loss: 0.3217 - val_precision: 0.7375 - val_recall: 0.4000 - val_binary_accuracy: 0.8636
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3181 - precision: 0.7292 - recall: 0.4172 - binary_accuracy: 0.8662 - val_loss: 0.3151 - val_precision: 0.7472 - val_recall: 0.4263 - val_binary_accuracy: 0.8681
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3182 - precision: 0.7298 - recall: 0.4190 - binary_accuracy: 0.8665 - val_loss: 0.3160 - val_precision: 0.7718 - val_recall: 0.3805 - val_binary_accuracy: 0.8655
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter25\assets
# Model 25evaluating:
# 94/94 [==============================] - 4s 36ms/step - loss: 0.3160 - precision: 0.7718 - recall: 0.3805 - binary_accuracy: 0.8655
# model loaded: iter25
# training model 26
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3177 - precision: 0.7282 - recall: 0.4183 - binary_accuracy: 0.8656 - val_loss: 0.3159 - val_precision: 0.7035 - val_recall: 0.4680 - val_binary_accuracy: 0.8678
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3174 - precision: 0.7306 - recall: 0.4171 - binary_accuracy: 0.8658 - val_loss: 0.3139 - val_precision: 0.7191 - val_recall: 0.4460 - val_binary_accuracy: 0.8680
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3169 - precision: 0.7276 - recall: 0.4201 - binary_accuracy: 0.8657 - val_loss: 0.3156 - val_precision: 0.7135 - val_recall: 0.4455 - val_binary_accuracy: 0.8671
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3177 - precision: 0.7286 - recall: 0.4148 - binary_accuracy: 0.8653 - val_loss: 0.3154 - val_precision: 0.7664 - val_recall: 0.3770 - val_binary_accuracy: 0.8662
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3168 - precision: 0.7333 - recall: 0.4198 - binary_accuracy: 0.8665 - val_loss: 0.3157 - val_precision: 0.7280 - val_recall: 0.4257 - val_binary_accuracy: 0.8671
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter26\assets
# Model 26evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3157 - precision: 0.7280 - recall: 0.4257 - binary_accuracy: 0.8671
# model loaded: iter26
# training model 27
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3186 - precision: 0.7312 - recall: 0.3985 - binary_accuracy: 0.8648 - val_loss: 0.3210 - val_precision: 0.7526 - val_recall: 0.3942 - val_binary_accuracy: 0.8633
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3176 - precision: 0.7253 - recall: 0.3989 - binary_accuracy: 0.8640 - val_loss: 0.3215 - val_precision: 0.7380 - val_recall: 0.4220 - val_binary_accuracy: 0.8648
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3181 - precision: 0.7316 - recall: 0.4027 - binary_accuracy: 0.8653 - val_loss: 0.3211 - val_precision: 0.7453 - val_recall: 0.4121 - val_binary_accuracy: 0.8646
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3175 - precision: 0.7313 - recall: 0.4052 - binary_accuracy: 0.8656 - val_loss: 0.3224 - val_precision: 0.7623 - val_recall: 0.3883 - val_binary_accuracy: 0.8638
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3177 - precision: 0.7336 - recall: 0.4064 - binary_accuracy: 0.8660 - val_loss: 0.3229 - val_precision: 0.7607 - val_recall: 0.3762 - val_binary_accuracy: 0.8621
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter27\assets
# Model 27evaluating:
# 94/94 [==============================] - 4s 36ms/step - loss: 0.3229 - precision: 0.7607 - recall: 0.3762 - binary_accuracy: 0.8621
# model loaded: iter27
# training model 28
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3081 - precision: 0.7283 - recall: 0.3944 - binary_accuracy: 0.8713 - val_loss: 0.3087 - val_precision: 0.7168 - val_recall: 0.3984 - val_binary_accuracy: 0.8730
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3075 - precision: 0.7368 - recall: 0.3960 - binary_accuracy: 0.8725 - val_loss: 0.3094 - val_precision: 0.7098 - val_recall: 0.4153 - val_binary_accuracy: 0.8737
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3072 - precision: 0.7283 - recall: 0.3942 - binary_accuracy: 0.8713 - val_loss: 0.3077 - val_precision: 0.7421 - val_recall: 0.3840 - val_binary_accuracy: 0.8746
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3081 - precision: 0.7307 - recall: 0.3965 - binary_accuracy: 0.8718 - val_loss: 0.3102 - val_precision: 0.7535 - val_recall: 0.3471 - val_binary_accuracy: 0.8717
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3075 - precision: 0.7322 - recall: 0.3943 - binary_accuracy: 0.8718 - val_loss: 0.3091 - val_precision: 0.7543 - val_recall: 0.3715 - val_binary_accuracy: 0.8746
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter28\assets
# Model 28evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3091 - precision: 0.7543 - recall: 0.3715 - binary_accuracy: 0.8746
# model loaded: iter28
# training model 29
# Samples Training Set: 15818
# Samples in Validation Data: 3390
# Samples in Test Data: 3390
# Batch size: 8
# SGD
# Epoch 1/5
# 1978/1978 [==============================] - 73s 36ms/step - loss: 0.3202 - precision: 0.7380 - recall: 0.4335 - binary_accuracy: 0.8645 - val_loss: 0.3219 - val_precision: 0.7670 - val_recall: 0.3983 - val_binary_accuracy: 0.8599
# Epoch 2/5
# 1978/1978 [==============================] - 72s 37ms/step - loss: 0.3201 - precision: 0.7329 - recall: 0.4339 - binary_accuracy: 0.8637 - val_loss: 0.3235 - val_precision: 0.7527 - val_recall: 0.4192 - val_binary_accuracy: 0.8607
# Epoch 3/5
# 1978/1978 [==============================] - 73s 37ms/step - loss: 0.3192 - precision: 0.7318 - recall: 0.4388 - binary_accuracy: 0.8641 - val_loss: 0.3210 - val_precision: 0.7210 - val_recall: 0.4747 - val_binary_accuracy: 0.8625
# Epoch 4/5
# 1978/1978 [==============================] - 73s 37ms/step - loss: 0.3193 - precision: 0.7380 - recall: 0.4417 - binary_accuracy: 0.8655 - val_loss: 0.3268 - val_precision: 0.6844 - val_recall: 0.5040 - val_binary_accuracy: 0.8588
# Epoch 5/5
# 1978/1978 [==============================] - 73s 37ms/step - loss: 0.3188 - precision: 0.7353 - recall: 0.4377 - binary_accuracy: 0.8646 - val_loss: 0.3208 - val_precision: 0.7431 - val_recall: 0.4500 - val_binary_accuracy: 0.8632
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter29\assets
# Model 29evaluating:
# 106/106 [==============================] - 4s 36ms/step - loss: 0.3208 - precision: 0.7431 - recall: 0.4500 - binary_accuracy: 0.8632
# model loaded: iter29
# training model 30
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3154 - precision: 0.7312 - recall: 0.4140 - binary_accuracy: 0.8654 - val_loss: 0.3198 - val_precision: 0.7061 - val_recall: 0.4400 - val_binary_accuracy: 0.8648
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3160 - precision: 0.7320 - recall: 0.4131 - binary_accuracy: 0.8654 - val_loss: 0.3189 - val_precision: 0.7540 - val_recall: 0.3887 - val_binary_accuracy: 0.8657
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3155 - precision: 0.7347 - recall: 0.4103 - binary_accuracy: 0.8654 - val_loss: 0.3197 - val_precision: 0.7109 - val_recall: 0.4437 - val_binary_accuracy: 0.8659
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3153 - precision: 0.7315 - recall: 0.4148 - binary_accuracy: 0.8655 - val_loss: 0.3192 - val_precision: 0.7525 - val_recall: 0.3814 - val_binary_accuracy: 0.8646
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.
# model loaded: iter32
# training model 33
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 37ms/step - loss: 0.3185 - precision: 0.7253 - recall: 0.4046 - binary_accuracy: 0.8639 - val_loss: 0.3159 - val_precision: 0.7035 - val_recall: 0.4740 - val_binary_accuracy: 0.8710
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3174 - precision: 0.7317 - recall: 0.4040 - binary_accuracy: 0.8647 - val_loss: 0.3092 - val_precision: 0.7530 - val_recall: 0.4173 - val_binary_accuracy: 0.8721
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3170 - precision: 0.7305 - recall: 0.4066 - binary_accuracy: 0.8648 - val_loss: 0.3084 - val_precision: 0.7394 - val_recall: 0.4351 - val_binary_accuracy: 0.8723
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3179 - precision: 0.7287 - recall: 0.4056 - binary_accuracy: 0.8645 - val_loss: 0.3110 - val_precision: 0.7146 - val_recall: 0.4801 - val_binary_accuracy: 0.8735
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3177 - precision: 0.7274 - recall: 0.4061 - binary_accuracy: 0.8643 - val_loss: 0.3102 - val_precision: 0.7289 - val_recall: 0.4524 - val_binary_accuracy: 0.8727
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter33\assets
# Model 33evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3102 - precision: 0.7289 - recall: 0.4524 - binary_accuracy: 0.8727
# model loaded: iter33
# training model 34
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3183 - precision: 0.7326 - recall: 0.4194 - binary_accuracy: 0.8657 - val_loss: 0.3215 - val_precision: 0.7240 - val_recall: 0.3957 - val_binary_accuracy: 0.8640
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3182 - precision: 0.7342 - recall: 0.4161 - binary_accuracy: 0.8655 - val_loss: 0.3228 - val_precision: 0.6836 - val_recall: 0.4669 - val_binary_accuracy: 0.8651
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3174 - precision: 0.7290 - recall: 0.4223 - binary_accuracy: 0.8655 - val_loss: 0.3199 - val_precision: 0.7319 - val_recall: 0.4017 - val_binary_accuracy: 0.8658
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3177 - precision: 0.7332 - recall: 0.4197 - binary_accuracy: 0.8658 - val_loss: 0.3198 - val_precision: 0.7241 - val_recall: 0.4179 - val_binary_accuracy: 0.8665
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3175 - precision: 0.7341 - recall: 0.4219 - binary_accuracy: 0.8662 - val_loss: 0.3217 - val_precision: 0.6937 - val_recall: 0.4558 - val_binary_accuracy: 0.8658
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter34\assets
# Model 34evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3217 - precision: 0.6937 - recall: 0.4558 - binary_accuracy: 0.8658
# model loaded: iter34
# training model 35
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3150 - precision: 0.7416 - recall: 0.4286 - binary_accuracy: 0.8687 - val_loss: 0.3272 - val_precision: 0.6675 - val_recall: 0.4781 - val_binary_accuracy: 0.8641
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3146 - precision: 0.7378 - recall: 0.4310 - binary_accuracy: 0.8685 - val_loss: 0.3223 - val_precision: 0.7098 - val_recall: 0.4194 - val_binary_accuracy: 0.8655
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3144 - precision: 0.7420 - recall: 0.4294 - binary_accuracy: 0.8689 - val_loss: 0.3212 - val_precision: 0.7294 - val_recall: 0.3593 - val_binary_accuracy: 0.8616
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3144 - precision: 0.7426 - recall: 0.4335 - binary_accuracy: 0.8695 - val_loss: 0.3210 - val_precision: 0.7212 - val_recall: 0.3798 - val_binary_accuracy: 0.8628
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3148 - precision: 0.7371 - recall: 0.4297 - binary_accuracy: 0.8682 - val_loss: 0.3225 - val_precision: 0.7114 - val_recall: 0.4077 - val_binary_accuracy: 0.8645
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter35\assets
# Model 35evaluating:
# 94/94 [==============================] - 4s 36ms/step - loss: 0.3225 - precision: 0.7114 - recall: 0.4077 - binary_accuracy: 0.8645
# model loaded: iter35
# training model 36
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3156 - precision: 0.7305 - recall: 0.4206 - binary_accuracy: 0.8666 - val_loss: 0.3203 - val_precision: 0.7074 - val_recall: 0.4415 - val_binary_accuracy: 0.8654
# Epoch 2/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3160 - precision: 0.7327 - recall: 0.4187 - binary_accuracy: 0.8667 - val_loss: 0.3200 - val_precision: 0.7233 - val_recall: 0.4296 - val_binary_accuracy: 0.8666
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3160 - precision: 0.7371 - recall: 0.4196 - binary_accuracy: 0.8674 - val_loss: 0.3196 - val_precision: 0.7233 - val_recall: 0.4162 - val_binary_accuracy: 0.8651
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3163 - precision: 0.7338 - recall: 0.4200 - binary_accuracy: 0.8670 - val_loss: 0.3208 - val_precision: 0.7358 - val_recall: 0.4089 - val_binary_accuracy: 0.8660
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3152 - precision: 0.7358 - recall: 0.4199 - binary_accuracy: 0.8673 - val_loss: 0.3218 - val_precision: 0.6985 - val_recall: 0.4562 - val_binary_accuracy: 0.8655
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter36\assets
# Model 36evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3218 - precision: 0.6985 - recall: 0.4562 - binary_accuracy: 0.8655
# model loaded: iter36
# training model 37
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3198 - precision: 0.7296 - recall: 0.3945 - binary_accuracy: 0.8641 - val_loss: 0.3124 - val_precision: 0.7332 - val_recall: 0.4292 - val_binary_accuracy: 0.8677
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3201 - precision: 0.7232 - recall: 0.3995 - binary_accuracy: 0.8638 - val_loss: 0.3163 - val_precision: 0.7589 - val_recall: 0.3720 - val_binary_accuracy: 0.8643
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3193 - precision: 0.7279 - recall: 0.3948 - binary_accuracy: 0.8639 - val_loss: 0.3118 - val_precision: 0.7543 - val_recall: 0.3852 - val_binary_accuracy: 0.8653
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3192 - precision: 0.7261 - recall: 0.4006 - binary_accuracy: 0.8643 - val_loss: 0.3128 - val_precision: 0.7203 - val_recall: 0.4329 - val_binary_accuracy: 0.8662
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3191 - precision: 0.7272 - recall: 0.4001 - binary_accuracy: 0.8644 - val_loss: 0.3118 - val_precision: 0.7625 - val_recall: 0.3839 - val_binary_accuracy: 0.8662
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter37\assets
# Model 37evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3118 - precision: 0.7625 - recall: 0.3839 - binary_accuracy: 0.8662
# model loaded: iter37
# training model 38
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3078 - precision: 0.7275 - recall: 0.3916 - binary_accuracy: 0.8707 - val_loss: 0.3038 - val_precision: 0.7487 - val_recall: 0.4123 - val_binary_accuracy: 0.8723
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3076 - precision: 0.7250 - recall: 0.3881 - binary_accuracy: 0.8700 - val_loss: 0.3021 - val_precision: 0.7502 - val_recall: 0.4227 - val_binary_accuracy: 0.8737
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3071 - precision: 0.7296 - recall: 0.3967 - binary_accuracy: 0.8715 - val_loss: 0.3043 - val_precision: 0.7939 - val_recall: 0.3815 - val_binary_accuracy: 0.8738
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3080 - precision: 0.7366 - recall: 0.3921 - binary_accuracy: 0.8718 - val_loss: 0.3049 - val_precision: 0.7478 - val_recall: 0.4090 - val_binary_accuracy: 0.8718
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3077 - precision: 0.7315 - recall: 0.3966 - binary_accuracy: 0.8717 - val_loss: 0.3072 - val_precision: 0.7443 - val_recall: 0.4028 - val_binary_accuracy: 0.8707
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter38\assets
# Model 38evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3072 - precision: 0.7443 - recall: 0.4028 - binary_accuracy: 0.8707
# model loaded: iter38
# training model 39
# Samples Training Set: 15818
# Samples in Validation Data: 3390
# Samples in Test Data: 3390
# Batch size: 8
# SGD
# Epoch 1/5
# 1978/1978 [==============================] - 74s 36ms/step - loss: 0.3196 - precision: 0.7383 - recall: 0.4423 - binary_accuracy: 0.8647 - val_loss: 0.3150 - val_precision: 0.7690 - val_recall: 0.4152 - val_binary_accuracy: 0.8645
5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3163 - precision: 0.7332 - recall: 0.4216 - binary_accuracy: 0.8668 - val_loss: 0.3254 - val_precision: 0.6933 - val_recall: 0.4542 - val_binary_accuracy: 0.8634
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3159 - precision: 0.7354 - recall: 0.4187 - binary_accuracy: 0.8668 - val_loss: 0.3191 - val_precision: 0.7450 - val_recall: 0.4114 - val_binary_accuracy: 0.8666
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter41\assets
# Model 41evaluating:
# 94/94 [==============================] - 4s 36ms/step - loss: 0.3191 - precision: 0.7450 - recall: 0.4114 - binary_accuracy: 0.8666
# model loaded: iter41
# training model 42
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3161 - precision: 0.7394 - recall: 0.4218 - binary_accuracy: 0.8667 - val_loss: 0.3195 - val_precision: 0.7202 - val_recall: 0.4776 - val_binary_accuracy: 0.8699
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3149 - precision: 0.7345 - recall: 0.4242 - binary_accuracy: 0.8662 - val_loss: 0.3181 - val_precision: 0.7537 - val_recall: 0.4177 - val_binary_accuracy: 0.8679
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3149 - precision: 0.7481 - recall: 0.4273 - binary_accuracy: 0.8685 - val_loss: 0.3195 - val_precision: 0.7898 - val_recall: 0.3646 - val_binary_accuracy: 0.8654
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3153 - precision: 0.7416 - recall: 0.4205 - binary_accuracy: 0.8668 - val_loss: 0.3212 - val_precision: 0.7708 - val_recall: 0.3692 - val_binary_accuracy: 0.8639
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3159 - precision: 0.7370 - recall: 0.4181 - binary_accuracy: 0.8659 - val_loss: 0.3204 - val_precision: 0.7054 - val_recall: 0.4766 - val_binary_accuracy: 0.8673
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter42\assets
# Model 42evaluating:
# 94/94 [==============================] - 4s 36ms/step - loss: 0.3204 - precision: 0.7054 - recall: 0.4766 - binary_accuracy: 0.8673
# model loaded: iter42
# training model 43
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3163 - precision: 0.7292 - recall: 0.4091 - binary_accuracy: 0.8655 - val_loss: 0.3303 - val_precision: 0.6677 - val_recall: 0.4887 - val_binary_accuracy: 0.8612
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3162 - precision: 0.7301 - recall: 0.4061 - binary_accuracy: 0.8653 - val_loss: 0.3214 - val_precision: 0.7436 - val_recall: 0.3795 - val_binary_accuracy: 0.8618
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3156 - precision: 0.7358 - recall: 0.4065 - binary_accuracy: 0.8661 - val_loss: 0.3243 - val_precision: 0.7063 - val_recall: 0.4389 - val_binary_accuracy: 0.8632
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3155 - precision: 0.7315 - recall: 0.4056 - binary_accuracy: 0.8655 - val_loss: 0.3224 - val_precision: 0.7122 - val_recall: 0.4370 - val_binary_accuracy: 0.8639
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.
5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3153 - precision: 0.7387 - recall: 0.4255 - binary_accuracy: 0.8682 - val_loss: 0.3231 - val_precision: 0.6625 - val_recall: 0.4922 - val_binary_accuracy: 0.8654
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter45\assets
# Model 45evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3231 - precision: 0.6625 - recall: 0.4922 - binary_accuracy: 0.8654
# model loaded: iter45
# training model 46
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3163 - precision: 0.7322 - recall: 0.4195 - binary_accuracy: 0.8665 - val_loss: 0.3179 - val_precision: 0.7252 - val_recall: 0.4430 - val_binary_accuracy: 0.8643
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3161 - precision: 0.7329 - recall: 0.4195 - binary_accuracy: 0.8666 - val_loss: 0.3191 - val_precision: 0.7665 - val_recall: 0.3874 - val_binary_accuracy: 0.8633
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3156 - precision: 0.7315 - recall: 0.4221 - binary_accuracy: 0.8667 - val_loss: 0.3214 - val_precision: 0.7881 - val_recall: 0.3544 - val_binary_accuracy: 0.8613
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3154 - precision: 0.7337 - recall: 0.4224 - binary_accuracy: 0.8670 - val_loss: 0.3181 - val_precision: 0.7367 - val_recall: 0.4199 - val_binary_accuracy: 0.8633
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3158 - precision: 0.7283 - recall: 0.4183 - binary_accuracy: 0.8658 - val_loss: 0.3177 - val_precision: 0.7424 - val_recall: 0.4234 - val_binary_accuracy: 0.8646
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter46\assets
# Model 46evaluating:
# 94/94 [==============================] - 4s 36ms/step - loss: 0.3177 - precision: 0.7424 - recall: 0.4234 - binary_accuracy: 0.8646
# model loaded: iter46
# training model 47
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3184 - precision: 0.7297 - recall: 0.4047 - binary_accuracy: 0.8650 - val_loss: 0.3184 - val_precision: 0.7299 - val_recall: 0.4082 - val_binary_accuracy: 0.8635
# Epoch 2/5
# 1750/1750 [==============================] - 64s 36ms/step - loss: 0.3183 - precision: 0.7293 - recall: 0.4053 - binary_accuracy: 0.8650 - val_loss: 0.3180 - val_precision: 0.7244 - val_recall: 0.4304 - val_binary_accuracy: 0.8652
# Epoch 3/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3180 - precision: 0.7315 - recall: 0.4036 - binary_accuracy: 0.8652 - val_loss: 0.3190 - val_precision: 0.7014 - val_recall: 0.4517 - val_binary_accuracy: 0.8639
# Epoch 4/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3179 - precision: 0.7386 - recall: 0.4059 - binary_accuracy: 0.8664 - val_loss: 0.3180 - val_precision: 0.7043 - val_recall: 0.4494 - val_binary_accuracy: 0.8642
# Epoch 5/5
# 1750/1750 [==============================] - 64s 37ms/step - loss: 0.3183 - precision: 0.7268 - recall: 0.4031 - binary_accuracy: 0.8644 - val_loss: 0.3158 - val_precision: 0.7538 - val_recall: 0.3873 - val_binary_accuracy: 0.8642
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter47\assets
# Model 47evaluating:
# 94/94 [==============================] - 4s 37ms/step - loss: 0.3158 - precision: 0.7538 - recall: 0.3873 - binary_accuracy: 0.8642
# model loaded: iter47
# training model 48
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# SGD
# Epoch 1/5
# 1750/1750 [==============================] - 65s 36ms/step - loss: 0.3062 - precision: 0.7398 - recall: 0.3995 - binary_accuracy: 0.8728 - val_loss: 0.3114 - val_precision: 0.6852 - val_recall: 0.4350 - val_binary_accuracy: 0.8721
# Epoch 2/5
# 1750/1750 [==============================] - 14606s 8s/step - loss: 0.3063 - precision: 0.7365 - recall: 0.3985 - binary_accuracy: 0.8723 - val_loss: 0.3087 - val_precision: 0.7135 - val_recall: 0.3871 - val_binary_accuracy: 0.8715
# Epoch 3/5
# 1467/1750 [========================>.....] - ETA: 9s - loss: 0.3042 - precision: 0.7430 - recall: 0.4052 - binary_accuracy: 0.8743
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12524/2838157247.py in <module>
#     106           opt = tf.keras.optimizers.Adam(learning_rate=0.001)
#     107           model.compile(optimizer = opt,loss="binary_crossentropy",metrics= ["binary_accuracy"])#tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 'binary_accuracy'])
# --> 108     training_process = model.fit(X_train,y_train,epochs = 5,validation_data = (X_val,y_val),batch_size=BATCH_SIZE,shuffle = True)
#     109     model.save('cnn82_checkpoints/iter'+str(i))
#     110     print("Model " + str(i) +"evaluating:")
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
attr_data_path = "list_attr_celeba.csv"
images_data_path = "C:/Users/foreh/Documents/celeba/greyscale"

tf.keras.backend.clear_session()
width = 178
height = 218
df_org = pd.read_csv(attr_data_path)

df = df_org[190000:202600]
df = df.replace(-1,0)
#print(df.head(5))
images_data = list()
for idx in range(df.shape[0]):
    path = "{}/{}".format(str(images_data_path),str(df.iloc[idx].image_id))
    image = PIL.Image.open(path)
    image_array = np.asarray(image)
    images_data.append(image_array)
images_data = np.array(images_data)
def image_from_index(index, size=(width,height), path=images_data_path):
    path = "{}/{}".format(str(path),str(df.iloc[index].image_id))
    # to read the image
    image = PIL.Image.open(path).resize(size)
    image_array = np.asarray(image)

    return image_array
images = images_data # list of array of images
labels = df[["image_id", "Bangs", "Straight_Hair", "Wavy_Hair", "Wearing_Hat"]]  # dataframe of image features
labels=labels.drop(["image_id"],axis=1)

# %%
for i in range(1, 48):
    tf.keras.backend.clear_session()
    print("###### EVAL MODEL "+str(i)+"######")
    model1 = tf.keras.models.load_model('cnn82_checkpoints/iter'+str(i))
    model1.evaluate(images,labels)
# Out:
# ###### EVAL MODEL 1######
# 394/394 [==============================] - 13s 33ms/step - loss: 0.3811 - precision: 0.7338 - recall: 0.3717 - binary_accuracy: 0.8533
# ###### EVAL MODEL 2######
# 394/394 [==============================] - 13s 32ms/step - loss: 0.3645 - precision: 0.7558 - recall: 0.3743 - binary_accuracy: 0.8564
# ###### EVAL MODEL 3######
# 394/394 [==============================] - 13s 33ms/step - loss: 0.3611 - precision: 0.7592 - recall: 0.3644 - binary_accuracy: 0.8556
# ###### EVAL MODEL 4######
# 394/394 [==============================] - 13s 33ms/step - loss: 0.3624 - precision: 0.8057 - recall: 0.2902 - binary_accuracy: 0.8501
# ###### EVAL MODEL 5######
# 394/394 [==============================] - 14s 33ms/step - loss: 0.3366 - precision: 0.7574 - recall: 0.3885 - binary_accuracy: 0.8585
# ###### EVAL MODEL 6######
# 394/394 [==============================] - 13s 33ms/step - loss: 0.3362 - precision: 0.7645 - recall: 0.3773 - binary_accuracy: 0.8579
# ###### EVAL MODEL 7######
# 394/394 [==============================] - 13s 33ms/step - loss: 0.3459 - precision: 0.7452 - recall: 0.3408 - binary_accuracy: 0.8508
# ###### EVAL MODEL 8######
# 394/394 [==============================] - 13s 33ms/step - loss: 0.3311 - precision: 0.7686 - recall: 0.3804 - binary_accuracy: 0.8588
# ###### EVAL MODEL 9######
# 394/394 [==============================] - 14s 33ms/step - loss: 0.3257 - precision: 0.7167 - recall: 0.4705 - binary_accuracy: 0.8624
# ###### EVAL MODEL 10######
# 394/394 [==============================] - 14s 33ms/step - loss: 0.3281 - precision: 0.7826 - recall: 0.3649 - binary_accuracy: 0.8584
# ###### EVAL MODEL 11######
# 394/394 [==============================] - 14s 33ms/step - loss: 0.3255 - precision: 0.7682 - recall: 0.3973 - binary_accuracy: 0.8611
# ###### EVAL MODEL 12######
# 394/394 [==============================] - 14s 33ms/step - loss: 0.3269 - precision: 0.7866 - recall: 0.3667 - binary_accuracy: 0.8591
# ###### EVAL MODEL 13######
# 394/394 [==============================] - 14s 34ms/step - loss: 0.3250 - precision: 0.7510 - recall: 0.4201 - binary_accuracy: 0.8617
# ###### EVAL MODEL 14######
# 394/394 [==============================] - 14s 34ms/step - loss: 0.3243 - precision: 0.7632 - recall: 0.4068 - binary_accuracy: 0.8617
# ###### EVAL MODEL 15######
# 394/394 [==============================] - 14s 34ms/step - loss: 0.3245 - precision: 0.7458 - recall: 0.4396 - binary_accuracy: 0.8634
# ###### EVAL MODEL 16######
# 394/394 [==============================] - 14s 34ms/step - loss: 0.3269 - precision: 0.7783 - recall: 0.3696 - binary_accuracy: 0.8585
# ###### EVAL MODEL 17######
# 394/394 [==============================] - 14s 34ms/step - loss: 0.3235 - precision: 0.7641 - recall: 0.4040 - binary_accuracy: 0.8614
# 394/394 [==============================] - 14s 35ms/step - loss: 0.3211 - precision: 0.7358 - recall: 0.4541 - binary_accuracy: 0.8637
# ###### EVAL MODEL 37######
# 394/394 [==============================] - 14s 34ms/step - loss: 0.3219 - precision: 0.7874 - recall: 0.3768 - binary_accuracy: 0.8606
# ###### EVAL MODEL 38######
# 394/394 [==============================] - 14s 34ms/step - loss: 0.3236 - precision: 0.7840 - recall: 0.3821 - binary_accuracy: 0.8610
# ###### EVAL MODEL 39######
# 394/394 [==============================] - 14s 34ms/step - loss: 0.3247 - precision: 0.7186 - recall: 0.4533 - binary_accuracy: 0.8607
# ###### EVAL MODEL 40######
# 394/394 [==============================] - 14s 35ms/step - loss: 0.3189 - precision: 0.7376 - recall: 0.4669 - binary_accuracy: 0.8656
# ###### EVAL MODEL 41######
# 394/394 [==============================] - 14s 34ms/step - loss: 0.3204 - precision: 0.7772 - recall: 0.4004 - binary_accuracy: 0.8626
# ###### EVAL MODEL 42######
# 394/394 [==============================] - 14s 34ms/step - loss: 0.3208 - precision: 0.7171 - recall: 0.4796 - binary_accuracy: 0.8636
# ###### EVAL MODEL 43######
# 394/394 [==============================] - 14s 35ms/step - loss: 0.3232 - precision: 0.7623 - recall: 0.4037 - binary_accuracy: 0.8611
# ###### EVAL MODEL 44######
# 394/394 [==============================] - 14s 35ms/step - loss: 0.3244 - precision: 0.7626 - recall: 0.3998 - binary_accuracy: 0.8607
# ###### EVAL MODEL 45######
# 394/394 [==============================] - 14s 35ms/step - loss: 0.3272 - precision: 0.6995 - recall: 0.4925 - binary_accuracy: 0.8617
# ###### EVAL MODEL 46######
# 394/394 [==============================] - 14s 35ms/step - loss: 0.3197 - precision: 0.7605 - recall: 0.4200 - binary_accuracy: 0.8630
# ###### EVAL MODEL 47######
# 377/394 [===========================>..] - ETA: 0s - loss: 0.3215 - precision: 0.7710 - recall: 0.3881 - binary_accuracy: 0.8601
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12136/2705320145.py in <module>
#       3     print("###### EVAL MODEL "+str(i)+"######")
#       4     model1 = tf.keras.models.load_model('cnn82_checkpoints/iter'+str(i))
# ----> 5     model1.evaluate(images,labels)
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1714             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1715               callbacks.on_test_batch_begin(step)
# -> 1716               tmp_logs = self.test_function(iterator)
#    1717               if data_handler.should_sync:
#    1718                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
