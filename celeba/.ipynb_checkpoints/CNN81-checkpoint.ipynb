# %%
import numpy as np
import pandas as pd
import PIL
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D
from tensorflow.keras.preprocessing import image

# %%
attr_data_path = "list_attr_celeba.csv"
images_data_path = "C:/Users/foreh/Documents/celeba/greyscale"
images_data_size = 20000 

tf.keras.backend.clear_session()
width = 178
height = 218
x_ = 100                            # new value of x
image_size_ratio = width / height    # dimensions ratio
y_ = int(image_size_ratio * x_)  
model = Sequential()
model.add(tf.keras.Input(shape=(height, width,1)))
model.add(tf.keras.layers.Normalization())

model.add(Conv2D(filters=32,kernel_size=(3,3),padding = 'same', kernel_regularizer='l2'))
model.add(Conv2D(filters=8, kernel_size=(3,3), padding='same', kernel_regularizer='l2'))
model.add(tf.keras.layers.Normalization())

model.add(Conv2D(filters=4, kernel_size=(3, 3), padding='same', kernel_regularizer='l2'))
model.add(MaxPooling2D(pool_size=2))

model.add(Dropout(0.2))

model.add(Conv2D(filters=32,kernel_size=(3,3),padding = 'same', kernel_regularizer='l2'))
model.add(Conv2D(filters=8,kernel_size=(2,2),padding = 'same', kernel_regularizer='l2'))
model.add(tf.keras.layers.Normalization())

model.add(Conv2D(filters=4, kernel_size=(3, 3), padding='same', kernel_regularizer='l2'))
model.add(MaxPooling2D(pool_size=2))

model.add(Dropout(0.2))

model.add(Conv2D(filters=16,kernel_size=(3,3),padding = 'same', kernel_regularizer='l2'))
model.add(Conv2D(filters=8,kernel_size=(2,2),padding = 'same', kernel_regularizer='l2'))
model.add(tf.keras.layers.Normalization())

model.add(Conv2D(filters=4, kernel_size=(3, 3), padding='same', kernel_regularizer='l2'))
model.add(MaxPooling2D(pool_size=4))

model.add(Conv2D(filters=16, kernel_size=(3,3)))
model.add(Conv2D(filters=16, kernel_size=(2,2)))
model.add(tf.keras.layers.AveragePooling2D(pool_size=2))

model.add(tf.keras.layers.Normalization())

model.add(Flatten())
model.add(Dense(64))
model.add(Dense(32))
model.add(Dense(48))
model.add(Dense(16))
model.add(Dense(4, activation='sigmoid'))
original_image_size = (width,height)
df_org = pd.read_csv(attr_data_path)

for i in range(10, 100):
    if (i > 1):
        model = tf.keras.models.load_model('cnn82_checkpoints/iter'+str(i-1))
        print("model loaded: iter"+str(i-1))
        print("training model "+str(i))
    df = pd.DataFrame()
    if((i+1) % 10 == 0):
        df = df_org[(1+images_data_size*(i%10)):202600]
    else:
        df = df_org[(1+images_data_size*(i%10)):images_data_size*((i+1)%10)]
    df = df.replace(-1,0)
    #print(df.head(5))
    images_data = list()
    for idx in range(df.shape[0]):
        path = "{}/{}".format(str(images_data_path),str(df.iloc[idx].image_id))
        image = PIL.Image.open(path)
        image_array = np.asarray(image)
        images_data.append(image_array)
    images_data = np.array(images_data)
    def image_from_index(index, size=(original_image_size), path=images_data_path):
        path = "{}/{}".format(str(path),str(df.iloc[index].image_id))
        # to read the image
        image = PIL.Image.open(path).resize(size)
        image_array = np.asarray(image)

        return image_array
    images = images_data # list of array of images
    labels = df[["image_id", "Bangs", "Straight_Hair", "Wavy_Hair", "Wearing_Hat"]]  # dataframe of image features
    train_images,test_images,train_labels,test_labels = train_test_split(images,labels,test_size=0.3,random_state=(i%6))
    y_test=test_labels.drop(["image_id"],axis=1)
    y_train=train_labels.drop(["image_id"],axis=1)

    X_test=test_images
    X_train=train_images
    #X_train = tf.expand_dims(X_train, axis=-1)
    print("Samples Training Set:",len(X_train))
    X_test, X_val, y_test, y_val=train_test_split(X_test, y_test,test_size=0.5,random_state=(i%5))
    print("Samples in Validation Data:",len(X_val))
    print("Samples in Test Data:",len(X_test))
    x_ = original_image_size[0]
    y_ = original_image_size[1]
    BATCH_SIZE = (8)
    print("Batch size: " + str(BATCH_SIZE))
    if False and i%3 == 1:
          model.compile(optimizer = "nadam",loss="binary_crossentropy",metrics = [tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 'binary_accuracy'])
    elif True or i%3 == 2 or i%3 == 0:
          print("SGD")
          opt = tf.keras.optimizers.SGD(learning_rate=0.001)
          model.compile(optimizer = opt,loss="binary_crossentropy",metrics = [tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 'binary_accuracy'])
    else:
          print("ADAM")
          opt = tf.keras.optimizers.Adam(learning_rate=0.001)
          model.compile(optimizer = opt,loss="binary_crossentropy",metrics= ["binary_accuracy"])#tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 'binary_accuracy'])
    training_process = model.fit(X_train,y_train,epochs = 5,validation_data = (X_val,y_val),batch_size=BATCH_SIZE,shuffle = True)
    model.save('cnn82_checkpoints/iter'+str(i))
    print("Model " + str(i) +"evaluating:")
    model.evaluate(X_val,y_val)
    tf.keras.backend.clear_session()
# Out:
# model loaded: iter8
# training model 9
# Samples Training Set: 15818
# Samples in Validation Data: 3390
# Samples in Test Data: 3390
# Batch size: 8
# SGD
# Epoch 1/5
# 1978/1978 [==============================] - 71s 32ms/step - loss: 0.3283 - precision: 0.7394 - recall: 0.4256 - binary_accuracy: 0.8629 - val_loss: 0.3249 - val_precision: 0.7243 - val_recall: 0.4708 - val_binary_accuracy: 0.8647
# Epoch 2/5
# 1978/1978 [==============================] - 64s 32ms/step - loss: 0.3268 - precision: 0.7364 - recall: 0.4337 - binary_accuracy: 0.8634 - val_loss: 0.3241 - val_precision: 0.7427 - val_recall: 0.4415 - val_binary_accuracy: 0.8642
# Epoch 3/5
# 1978/1978 [==============================] - 65s 33ms/step - loss: 0.3262 - precision: 0.7394 - recall: 0.4323 - binary_accuracy: 0.8637 - val_loss: 0.3205 - val_precision: 0.7466 - val_recall: 0.4450 - val_binary_accuracy: 0.8652
# Epoch 4/5
# 1978/1978 [==============================] - 66s 34ms/step - loss: 0.3257 - precision: 0.7415 - recall: 0.4334 - binary_accuracy: 0.8641 - val_loss: 0.3195 - val_precision: 0.7423 - val_recall: 0.4538 - val_binary_accuracy: 0.8656
# Epoch 5/5
# 1978/1978 [==============================] - 67s 34ms/step - loss: 0.3260 - precision: 0.7371 - recall: 0.4328 - binary_accuracy: 0.8634 - val_loss: 0.3216 - val_precision: 0.7171 - val_recall: 0.4778 - val_binary_accuracy: 0.8643
# INFO:tensorflow:Assets written to: cnn82_checkpoints/iter9\assets
# Model 9evaluating:
# 106/106 [==============================] - 5s 40ms/step - loss: 0.3216 - precision: 0.7171 - recall: 0.4778 - binary_accuracy: 0.8643
# model loaded: iter9
# training model 10
# Samples Training Set: 13999
# Samples in Validation Data: 3000
# Samples in Test Data: 3000
# Batch size: 8
# Epoch 1/5
# 1750/1750 [==============================] - 84s 46ms/step - loss: 0.3388 - precision: 0.7135 - recall: 0.3670 - binary_accuracy: 0.8574 - val_loss: 0.3312 - val_precision: 0.7757 - val_recall: 0.3376 - val_binary_accuracy: 0.8598
# Epoch 2/5
# 1750/1750 [==============================] - 82s 47ms/step - loss: 0.3391 - precision: 0.7154 - recall: 0.3661 - binary_accuracy: 0.8576 - val_loss: 0.3247 - val_precision: 0.7969 - val_recall: 0.3439 - val_binary_accuracy: 0.8628
# Epoch 3/5
# 1750/1750 [==============================] - 84s 48ms/step - loss: 0.3343 - precision: 0.7179 - recall: 0.3731 - binary_accuracy: 0.8587 - val_loss: 0.3318 - val_precision: 0.7424 - val_recall: 0.4062 - val_binary_accuracy: 0.8645
# Epoch 4/5
#  247/1750 [===>..........................] - ETA: 1:07 - loss: 0.3375 - precision: 0.7231 - recall: 0.3685 - binary_accuracy: 0.8573
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14820/4232286651.py in <module>
#     106           opt = tf.keras.optimizers.Adam(learning_rate=0.001)
#     107           model.compile(optimizer = opt,loss="binary_crossentropy",metrics= ["binary_accuracy"])#tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), 'binary_accuracy'])
# --> 108     training_process = model.fit(X_train,y_train,epochs = 5,validation_data = (X_val,y_val),batch_size=BATCH_SIZE,shuffle = True)
#     109     model.save('cnn82_checkpoints/iter'+str(i))
#     110     print("Model " + str(i) +"evaluating:")
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# ~\anaconda3\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# ~\anaconda3\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# ~\anaconda3\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~\anaconda3\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# ~\anaconda3\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# ~\anaconda3\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# ~\anaconda3\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# ~\anaconda3\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
attr_data_path = "list_attr_celeba.csv"
images_data_path = "C:/Users/foreh/Documents/celeba/greyscale"

tf.keras.backend.clear_session()
width = 178
height = 218
df_org = pd.read_csv(attr_data_path)

df = df_org[190000:202600]
df = df.replace(-1,0)
#print(df.head(5))
images_data = list()
for idx in range(df.shape[0]):
    path = "{}/{}".format(str(images_data_path),str(df.iloc[idx].image_id))
    image = PIL.Image.open(path)
    image_array = np.asarray(image)
    images_data.append(image_array)
images_data = np.array(images_data)
def image_from_index(index, size=(width,height), path=images_data_path):
    path = "{}/{}".format(str(path),str(df.iloc[index].image_id))
    # to read the image
    image = PIL.Image.open(path).resize(size)
    image_array = np.asarray(image)

    return image_array
images = images_data # list of array of images
labels = df[["image_id", "Bangs", "Straight_Hair", "Wavy_Hair", "Wearing_Hat"]]  # dataframe of image features
labels=labels.drop(["image_id"],axis=1)

# %%
for i in range(1, 40):
    tf.keras.backend.clear_session()
    print("###### EVAL MODEL "+str(i)+"######")
    model1 = tf.keras.models.load_model('cnn81_checkpoints/iter'+str(i))
    model1.evaluate(images,labels)
